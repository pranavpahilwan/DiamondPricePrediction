# %% [markdown]
# ## Daimond Price Prediction

# %% [markdown]
# ### Introduction About the Data :
#
# **The dataset** The goal is to predict `price` of given diamond (Regression Analysis).
#
# There are 10 independent variables (including `id`):
#
# * `id` : unique identifier of each diamond
# * `carat` : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
# * `cut` : Quality of Diamond Cut
# * `color` : Color of Diamond
# * `clarity` : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
# * `depth` : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
# * `table` : A diamond's table is the facet which can be seen when the stone is viewed face up.
# * `x` : Diamond X dimension
# * `y` : Diamond Y dimension
# * `x` : Diamond Z dimension
#
# Target variable:
# * `price`: Price of the given Diamond.
#
# Dataset Source Link :
# [https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv](https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv)

# %%
import pandas as pd

# %%
# data ingestion steps
df = pd.read_csv('data/gemstone.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ### Observations
# - Our dataset consists of two integer feature, three object feature and rest float
# - Dataset has no missing values
# - Id column has no technical relation with the data. It is just the serial no. It will not add any value to our model.

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
# Drop Column ID
df= df.drop(labels=['id'],axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Observation
# - No duplicate records are found

# %%
# Segreagate the numerical and catgorical columns
numerical_columns = df.columns[df.dtypes!='object']
categorical_columns = df.columns[df.dtypes=='object']

# %%
numerical_columns
categorical_columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
print("numerical_columns:", numerical_columns)
print('categorical_columns:', categorical_columns)
# Out:
# numerical_columns: Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# categorical_columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df.describe()
# Out:
#                carat          depth          table              x  \
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean        0.790688      61.820574      57.227675       5.715312
# std         0.462688       1.081704       1.918844       1.109422
# min         0.200000      52.100000      49.000000       0.000000
# 25%         0.400000      61.300000      56.000000       4.700000
# 50%         0.700000      61.900000      57.000000       5.700000
# 75%         1.030000      62.400000      58.000000       6.510000
# max         3.500000      71.600000      79.000000       9.650000
#
#                    y              z          price
# count  193573.000000  193573.000000  193573.000000
# mean        5.720094       3.534246    3969.155414
# std         1.102333       0.688922    4034.374138
# min         0.000000       0.000000     326.000000
# 25%         4.710000       2.900000     951.000000
# 50%         5.720000       3.530000    2401.000000
# ...

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df, x=i, kde=True)
    print('\n')
    plt.show()

# %%
sns.catplot(x='cut',kind='count' ,data=df)
sns.catplot(x='clarity',kind='count' ,data=df)
sns.catplot(x='color',kind='count' ,data=df)

# %%
sns.catplot(x='cut',y='carat' ,data=df)
sns.catplot(x='clarity',y='carat' ,data=df)
sns.catplot(x='color',y='carat' ,data=df)

# %%
## Correlation
plt.figure(figsize=(10,8))
sns.heatmap(df[numerical_columns].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Observations
# - Some Independent feature are highly correlated with each other means they act same. Here feature X, Y, Z are highly correlated with feature "Carat" . So, we can drop these feature.

# %%
df=df.drop(labels=['x','y','z'],axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table  price
# 0   1.52    Premium     F     VS2   62.2   58.0  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0    666
# 4   1.70    Premium     G     VS2   62.6   59.0  14453

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
### Data Encoding
cut_map= {'Fair':1, 'Good':2, 'Very Good':3, 'Premium':4, 'Ideal':5}

# Here we have referred the american society website for ranking consideration of gemstones

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {'I1':1, 'SI2':2, 'SI1':3, 'VS2':4, 'VS1':5,'VVS2':6, 'VVS1':7, 'IF':8 }

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map={'D':1, 'E':2, 'F':3, 'G':4, 'H':5, 'I':6, 'J':7}

# %%
df['cut']=df['cut'].map(cut_map)
df['clarity']=df['clarity'].map(clarity_map)
df['color']=df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price
# 0   1.52    4      3        4   62.2   58.0  13619
# 1   2.03    3      7        2   62.0   58.0  13387
# 2   0.70    5      4        5   61.2   57.0   2772
# 3   0.32    5      4        5   61.6   56.0    666
# 4   1.70    4      4        4   62.6   59.0  14453

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >
